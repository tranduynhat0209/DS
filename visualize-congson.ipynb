# %%
### Task a: Mỗi enum (hướng nhà, ban công, nội thất, giấy tờ, đường rộng, Boolean)  vẽ 1 biểu đồ thể hiện tất cả giá trị (mỗi enum làm 1 box plot)

import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import kurtosis, skew



data_df = pd.read_csv("data-cleaned-v2/data-cleaned.csv", index_col=0)


### a.1: huong nha
states = data_df[''].unique()

### a.2: huong ban cong


### a.3: noi that


### a.4: giay to


### a.5: duong rong


### a.6: booleans

# data = []
# for i in range(0, 12):
#     a_state_df = state_price_per_sqft_df[state_price_per_sqft_df['state'] == states[i]]
#     data.append(a_state_df['Price/sqft'])
# data.append(state_price_per_sqft_df['Price/sqft'])
# labels = list(states)
# labels.append('all')
# fig, ax = plt.subplots(1)
# plt.title("State Price per sqft Boxplot")
# ax.set_xticklabels(labels)
# ax.boxplot(data)
# fig.set_figheight(10)
# fig.set_figwidth(20)
# plt.show()

# state = addr_df[["zpid", "state"]]
# price_per_sqft = basic_df[["zpid", "Price/sqft"]]

# state_price_per_sqft_df = pd.merge(state, price_per_sqft, how='inner', on='zpid')
# state_price_per_sqft_df = state_price_per_sqft_df.drop(columns=['zpid'])

# # state_price_per_sqft_df['Price/sqft']
# state_price_per_sqft_df['Price/sqft'] = state_price_per_sqft_df['Price/sqft'].map(lambda price: float(price.__str__().replace(',', '')) if price.__str__().isnumeric() else None)
# state_price_per_sqft_df = state_price_per_sqft_df.dropna(subset=['Price/sqft'])

# def price_sqft_histogram(state, ax):
#     a_state_df = state_price_per_sqft_df[state_price_per_sqft_df['state'] == state]
#     price_sqft = a_state_df['Price/sqft']

#     print(price_sqft )
#     k = kurtosis(price_sqft, fisher=False)
#     s = skew(price_sqft)
#     ax.set_ylabel("price/sqft")
#     ax.set_title(state + ' price per sqft histogram')
#     ax.set_xlabel('Kurtosis: ' + str(k) + ', Skew: ' + str(s))
#     ax.hist(price_sqft)


# states = state_price_per_sqft_df['state'].unique()
# fig, axs = plt.subplots(12)
# fig.suptitle("State Price per square foot Histogram")
# fig.set_figwidth(10)
# fig.set_figheight(12 * 10)

# for i in range(0, 12):
#     price_sqft_histogram(states[i], axs[i])

# plt.show()
# Out:
# 0      266.0
# 1      263.0
# 2      464.0
# 3      176.0
# 4      214.0
#        ...
# 125    575.0
# 126    236.0
# 127     99.0
# 128    140.0
# 129    338.0
# Name: Price/sqft, Length: 128, dtype: float64
# 130    109.0
# 131    132.0
# 132    123.0
# 133    147.0
# 134    105.0
#        ...
# 270    188.0
# 273    190.0
# 274    140.0
# 275    157.0
# 276     78.0
# Name: Price/sqft, Length: 97, dtype: float64
# 278    242.0
# 279    225.0
# 280    192.0
# 281    232.0
# 284    202.0
#        ...
# 417    117.0
# 418    163.0
# 421    247.0
# 422    327.0
# 424    233.0
# Name: Price/sqft, Length: 120, dtype: float64
# 426    147.0
# 427    361.0
# 428    113.0
# 429    102.0
# 430    203.0
#        ...
# 553    182.0
# 554    115.0
# 555    163.0
# 557    125.0
# 558    181.0
# Name: Price/sqft, Length: 114, dtype: float64
# 561    214.0
# 562    129.0
# 563    340.0
# 564    196.0
# 565    147.0
#        ...
# 697    157.0
# 698    230.0
# 699     66.0
# 700    166.0
# ...

# %%
data = []
for i in range(0, 12):
    a_state_df = state_price_per_sqft_df[state_price_per_sqft_df['state'] == states[i]]
    data.append(a_state_df['Price/sqft'])
data.append(state_price_per_sqft_df['Price/sqft'])
labels = list(states)
labels.append('all')
fig, ax = plt.subplots(1)
plt.title("State Price per sqft Boxplot")
ax.set_xticklabels(labels)
ax.boxplot(data)
fig.set_figheight(10)
fig.set_figwidth(20)
plt.show()
# Out:
# C:\Users\congs\AppData\Local\Temp\ipykernel_580\3743542690.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
